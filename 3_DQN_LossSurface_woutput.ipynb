# %%
# %mkdir save_model
# %mkdir save_graph

# %% [markdown]
# 파이썬과 케라스로 배우는 강화학습 [코드](https://github.com/rlcode/reinforcement-learning-kr-v2)를 참고하였습니다.

# %% [markdown]
# ### 1. 라이브러리 임폴트

# %%
import os
import sys
import gym
import pylab
import random
import numpy as np
from matplotlib import cm
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from collections import deque
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.initializers import RandomUniform

# %% [markdown]
# ### 2. DQN 모델 정의

# %%
# 상태가 입력, 큐함수가 출력인 인공신경망 생성
class DQN(tf.keras.Model):
    def __init__(self, action_size):
        super(DQN, self).__init__()
        self.fc1 = Dense(24, activation='relu')
        self.fc2 = Dense(24, activation='relu')
        self.fc_out = Dense(action_size,
                            kernel_initializer=RandomUniform(-1e-3, 1e-3))

    def call(self, x):
        x = self.fc1(x)
        x = self.fc2(x)
        q = self.fc_out(x)
        return q


# 카트폴 예제에서의 DQN 에이전트
class DQNAgent:
    def __init__(self, state_size, action_size):
        self.render = False

        # 상태와 행동의 크기 정의
        self.state_size = state_size
        self.action_size = action_size

        # DQN 하이퍼파라미터
        self.discount_factor = 0.99
        self.learning_rate = 0.001
        self.epsilon = 1.0
        self.epsilon_decay = 0.999
        self.epsilon_min = 0.01
        self.batch_size = 64
        self.train_start = 1000

        # 리플레이 메모리, 최대 크기 2000
        self.memory = deque(maxlen=2000)

        # 모델과 타깃 모델 생성
        self.model = DQN(action_size)
        self.target_model = DQN(action_size)
        self.optimizer = Adam(lr=self.learning_rate)

        # 타깃 모델 초기화
        self.update_target_model()

    # 타깃 모델을 모델의 가중치로 업데이트
    def update_target_model(self):
        self.target_model.set_weights(self.model.get_weights())

    # 입실론 탐욕 정책으로 행동 선택
    def get_action(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        else:
            q_value = self.model(state)
            return np.argmax(q_value[0])

    # 샘플 <s, a, r, s'>을 리플레이 메모리에 저장
    def append_sample(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    # 리플레이 메모리에서 무작위로 추출한 배치로 모델 학습
    def train_model(self):
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

        # 메모리에서 배치 크기만큼 무작위로 샘플 추출
        mini_batch = random.sample(self.memory, self.batch_size)

        states = np.array([sample[0][0] for sample in mini_batch])
        actions = np.array([sample[1] for sample in mini_batch])
        rewards = np.array([sample[2] for sample in mini_batch])
        next_states = np.array([sample[3][0] for sample in mini_batch])
        dones = np.array([sample[4] for sample in mini_batch])

        # 학습 파라메터
        model_params = self.model.trainable_variables
        with tf.GradientTape() as tape:
            # 현재 상태에 대한 모델의 큐함수
            predicts = self.model(states)
            one_hot_action = tf.one_hot(actions, self.action_size)
            predicts = tf.reduce_sum(one_hot_action * predicts, axis=1)

            # 다음 상태에 대한 타깃 모델의 큐함수
            target_predicts = self.target_model(next_states)
            target_predicts = tf.stop_gradient(target_predicts)

            # 벨만 최적 방정식을 이용한 업데이트 타깃
            max_q = np.amax(target_predicts, axis=-1)
            targets = rewards + (1 - dones) * self.discount_factor * max_q
            loss = tf.reduce_mean(tf.square(targets - predicts))

        # 오류함수를 줄이는 방향으로 모델 업데이트
        grads = tape.gradient(loss, model_params)
        self.optimizer.apply_gradients(zip(grads, model_params))

    def test_model(self):
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

        # 메모리에서 배치 크기만큼 무작위로 샘플 추출
        mini_batch = random.sample(self.memory, self.batch_size)

        states = np.array([sample[0][0] for sample in mini_batch])
        actions = np.array([sample[1] for sample in mini_batch])
        rewards = np.array([sample[2] for sample in mini_batch])
        next_states = np.array([sample[3][0] for sample in mini_batch])
        dones = np.array([sample[4] for sample in mini_batch])

        # 학습 파라메터
        model_params = self.model.trainable_variables
        with tf.GradientTape() as tape:
            # 현재 상태에 대한 모델의 큐함수
            predicts = self.model(states)
            one_hot_action = tf.one_hot(actions, self.action_size)
            predicts = tf.reduce_sum(one_hot_action * predicts, axis=1)

            # 다음 상태에 대한 타깃 모델의 큐함수
            target_predicts = self.target_model(next_states)
            target_predicts = tf.stop_gradient(target_predicts)

            # 벨만 최적 방정식을 이용한 업데이트 타깃
            max_q = np.amax(target_predicts, axis=-1)
            targets = rewards + (1 - dones) * self.discount_factor * max_q
            loss = tf.reduce_mean(tf.square(targets - predicts))

        return loss

# %% [markdown]
# ### 3. DQN 모델 학습

# %%
if __name__ == "__main__":
    # CartPole-v1 환경, 최대 타임스텝 수가 500
    env = gym.make('CartPole-v1')
    state_size = env.observation_space.shape[0]
    action_size = env.action_space.n

    # DQN 에이전트 생성
    agent = DQNAgent(state_size, action_size)

    scores, episodes = [], []
    score_avg = 0

    num_episode = 300
    for e in range(num_episode):
        done = False
        score = 0
        # env 초기화
        state = env.reset()
        state = np.reshape(state, [1, state_size])

        while not done:
            if agent.render:
                env.render()

            # 현재 상태로 행동을 선택
            action = agent.get_action(state)
            # 선택한 행동으로 환경에서 한 타임스텝 진행
            next_state, reward, done, info = env.step(action)
            next_state = np.reshape(next_state, [1, state_size])

            # 타임스텝마다 보상 0.1, 에피소드가 중간에 끝나면 -1 보상
            score += reward
            reward = 0.1 if not done or score == 500 else -1

            # 리플레이 메모리에 샘플 <s, a, r, s'> 저장
            agent.append_sample(state, action, reward, next_state, done)
            # 매 타임스텝마다 학습
            if len(agent.memory) >= agent.train_start:
                agent.train_model()

            state = next_state

            if done:
                # 각 에피소드마다 타깃 모델을 모델의 가중치로 업데이트
                agent.update_target_model()
                # 에피소드마다 학습 결과 출력
                score_avg = 0.9 * score_avg + 0.1 * score if score_avg != 0 else score
                print("episode: {:3d} | score avg: {:3.2f} | memory length: {:4d} | epsilon: {:.4f}".format(
                      e, score_avg, len(agent.memory), agent.epsilon))

                # 에피소드마다 학습 결과 그래프로 저장
                scores.append(score_avg)
                episodes.append(e)
                pylab.plot(episodes, scores, 'b')
                pylab.xlabel("episode")
                pylab.ylabel("average score")
                pylab.savefig("./save_graph/graph.png")

                # 이동 평균이 400 이상일 때 종료
                if score_avg > 400:
                    agent.model.save_weights("./save_model/model", save_format="tf")
                    sys.exit()
# Out:
# episode:   0 | score avg: 33.00 | memory length:   33 | epsilon: 1.0000
# episode:   1 | score avg: 31.70 | memory length:   53 | epsilon: 1.0000
# episode:   2 | score avg: 30.53 | memory length:   73 | epsilon: 1.0000
# episode:   3 | score avg: 29.08 | memory length:   89 | epsilon: 1.0000
# episode:   4 | score avg: 27.57 | memory length:  103 | epsilon: 1.0000
# episode:   5 | score avg: 26.61 | memory length:  121 | epsilon: 1.0000
# episode:   6 | score avg: 27.25 | memory length:  154 | epsilon: 1.0000
# episode:   7 | score avg: 25.63 | memory length:  165 | epsilon: 1.0000
# episode:   8 | score avg: 27.66 | memory length:  211 | epsilon: 1.0000
# episode:   9 | score avg: 27.20 | memory length:  234 | epsilon: 1.0000
# episode:  10 | score avg: 26.68 | memory length:  256 | epsilon: 1.0000
# episode:  11 | score avg: 25.31 | memory length:  269 | epsilon: 1.0000
# episode:  12 | score avg: 26.78 | memory length:  309 | epsilon: 1.0000
# episode:  13 | score avg: 25.50 | memory length:  323 | epsilon: 1.0000
# episode:  14 | score avg: 25.25 | memory length:  346 | epsilon: 1.0000
# episode:  15 | score avg: 23.83 | memory length:  357 | epsilon: 1.0000
# episode:  16 | score avg: 23.14 | memory length:  374 | epsilon: 1.0000
# episode:  17 | score avg: 23.33 | memory length:  399 | epsilon: 1.0000
# episode:  18 | score avg: 22.30 | memory length:  412 | epsilon: 1.0000
# episode:  19 | score avg: 22.47 | memory length:  436 | epsilon: 1.0000
# episode:  20 | score avg: 22.72 | memory length:  461 | epsilon: 1.0000
# episode:  21 | score avg: 22.95 | memory length:  486 | epsilon: 1.0000
# episode:  22 | score avg: 23.15 | memory length:  511 | epsilon: 1.0000
# episode:  23 | score avg: 24.14 | memory length:  544 | epsilon: 1.0000
# episode:  24 | score avg: 22.72 | memory length:  554 | epsilon: 1.0000
# episode:  25 | score avg: 21.65 | memory length:  566 | epsilon: 1.0000
# episode:  26 | score avg: 21.19 | memory length:  583 | epsilon: 1.0000
# episode:  27 | score avg: 19.97 | memory length:  592 | epsilon: 1.0000
# episode:  28 | score avg: 20.87 | memory length:  621 | epsilon: 1.0000
# episode:  29 | score avg: 22.48 | memory length:  658 | epsilon: 1.0000
# episode:  30 | score avg: 21.44 | memory length:  670 | epsilon: 1.0000
# episode:  31 | score avg: 20.79 | memory length:  685 | epsilon: 1.0000
# episode:  32 | score avg: 26.01 | memory length:  758 | epsilon: 1.0000
# episode:  33 | score avg: 25.31 | memory length:  777 | epsilon: 1.0000
# episode:  34 | score avg: 24.28 | memory length:  792 | epsilon: 1.0000
# episode:  35 | score avg: 23.25 | memory length:  806 | epsilon: 1.0000
# episode:  36 | score avg: 22.83 | memory length:  825 | epsilon: 1.0000
# episode:  37 | score avg: 22.04 | memory length:  840 | epsilon: 1.0000
# episode:  38 | score avg: 22.54 | memory length:  867 | epsilon: 1.0000
# episode:  39 | score avg: 22.09 | memory length:  885 | epsilon: 1.0000
# episode:  40 | score avg: 21.18 | memory length:  898 | epsilon: 1.0000
# episode:  41 | score avg: 21.76 | memory length:  925 | epsilon: 1.0000
# episode:  42 | score avg: 23.28 | memory length:  962 | epsilon: 1.0000
# episode:  43 | score avg: 23.86 | memory length:  991 | epsilon: 1.0000
# WARNING:tensorflow:Layer dqn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer dqn_1 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# episode:  44 | score avg: 24.77 | memory length: 1024 | epsilon: 0.9753
# episode:  45 | score avg: 23.59 | memory length: 1037 | epsilon: 0.9627
# episode:  46 | score avg: 23.13 | memory length: 1056 | epsilon: 0.9446
# episode:  47 | score avg: 21.82 | memory length: 1066 | epsilon: 0.9352
# episode:  48 | score avg: 20.94 | memory length: 1079 | epsilon: 0.9231
# episode:  49 | score avg: 20.24 | memory length: 1093 | epsilon: 0.9102
# episode:  50 | score avg: 19.42 | memory length: 1105 | epsilon: 0.8994
# episode:  51 | score avg: 18.78 | memory length: 1118 | epsilon: 0.8878
# episode:  52 | score avg: 18.30 | memory length: 1132 | epsilon: 0.8754
# episode:  53 | score avg: 18.07 | memory length: 1148 | epsilon: 0.8615
# episode:  54 | score avg: 18.26 | memory length: 1168 | epsilon: 0.8444
# episode:  55 | score avg: 19.14 | memory length: 1195 | epsilon: 0.8219
# episode:  56 | score avg: 24.02 | memory length: 1263 | epsilon: 0.7679
# episode:  57 | score avg: 28.02 | memory length: 1327 | epsilon: 0.7202
# episode:  58 | score avg: 28.62 | memory length: 1361 | epsilon: 0.6962
# episode:  59 | score avg: 28.86 | memory length: 1392 | epsilon: 0.6749
# episode:  60 | score avg: 29.97 | memory length: 1432 | epsilon: 0.6484
# episode:  61 | score avg: 28.47 | memory length: 1447 | epsilon: 0.6388
# episode:  62 | score avg: 27.43 | memory length: 1465 | epsilon: 0.6274
# episode:  63 | score avg: 26.18 | memory length: 1480 | epsilon: 0.6180
# episode:  64 | score avg: 28.17 | memory length: 1526 | epsilon: 0.5902
# episode:  65 | score avg: 42.05 | memory length: 1693 | epsilon: 0.4994
# episode:  66 | score avg: 54.54 | memory length: 1860 | epsilon: 0.4226
# episode:  67 | score avg: 54.19 | memory length: 1911 | epsilon: 0.4015
# episode:  68 | score avg: 59.97 | memory length: 2000 | epsilon: 0.3590
# episode:  69 | score avg: 59.87 | memory length: 2000 | epsilon: 0.3384
# episode:  70 | score avg: 64.59 | memory length: 2000 | epsilon: 0.3040
# episode:  71 | score avg: 73.43 | memory length: 2000 | epsilon: 0.2609
# episode:  72 | score avg: 84.98 | memory length: 2000 | epsilon: 0.2159
# episode:  73 | score avg: 98.59 | memory length: 2000 | epsilon: 0.1731
# episode:  74 | score avg: 107.93 | memory length: 2000 | epsilon: 0.1428
# episode:  75 | score avg: 116.33 | memory length: 2000 | epsilon: 0.1179
# episode:  76 | score avg: 134.10 | memory length: 2000 | epsilon: 0.0878
# episode:  77 | score avg: 147.59 | memory length: 2000 | epsilon: 0.0671
# episode:  78 | score avg: 151.73 | memory length: 2000 | epsilon: 0.0556
# episode:  79 | score avg: 166.36 | memory length: 2000 | epsilon: 0.0412
# episode:  80 | score avg: 174.82 | memory length: 2000 | epsilon: 0.0321
# episode:  81 | score avg: 178.14 | memory length: 2000 | epsilon: 0.0260
# episode:  82 | score avg: 181.83 | memory length: 2000 | epsilon: 0.0210
# episode:  83 | score avg: 184.94 | memory length: 2000 | epsilon: 0.0170
# episode:  84 | score avg: 191.45 | memory length: 2000 | epsilon: 0.0132
# episode:  85 | score avg: 197.00 | memory length: 2000 | epsilon: 0.0103
# episode:  86 | score avg: 200.20 | memory length: 2000 | epsilon: 0.0100
# episode:  87 | score avg: 200.28 | memory length: 2000 | epsilon: 0.0100
# episode:  88 | score avg: 197.36 | memory length: 2000 | epsilon: 0.0100
# episode:  89 | score avg: 198.92 | memory length: 2000 | epsilon: 0.0100
# episode:  90 | score avg: 197.73 | memory length: 2000 | epsilon: 0.0100
# episode:  91 | score avg: 204.36 | memory length: 2000 | epsilon: 0.0100
# episode:  92 | score avg: 206.32 | memory length: 2000 | epsilon: 0.0100
# episode:  93 | score avg: 205.69 | memory length: 2000 | epsilon: 0.0100
# episode:  94 | score avg: 203.52 | memory length: 2000 | epsilon: 0.0100
# episode:  95 | score avg: 204.37 | memory length: 2000 | epsilon: 0.0100
# episode:  96 | score avg: 202.33 | memory length: 2000 | epsilon: 0.0100
# episode:  97 | score avg: 199.40 | memory length: 2000 | epsilon: 0.0100
# episode:  98 | score avg: 196.06 | memory length: 2000 | epsilon: 0.0100
# episode:  99 | score avg: 195.05 | memory length: 2000 | epsilon: 0.0100
# episode: 100 | score avg: 190.65 | memory length: 2000 | epsilon: 0.0100
# episode: 101 | score avg: 190.48 | memory length: 2000 | epsilon: 0.0100
# episode: 102 | score avg: 186.63 | memory length: 2000 | epsilon: 0.0100
# episode: 103 | score avg: 184.97 | memory length: 2000 | epsilon: 0.0100
# episode: 104 | score avg: 193.67 | memory length: 2000 | epsilon: 0.0100
# episode: 105 | score avg: 189.51 | memory length: 2000 | epsilon: 0.0100
# episode: 106 | score avg: 187.56 | memory length: 2000 | epsilon: 0.0100
# episode: 107 | score avg: 196.00 | memory length: 2000 | epsilon: 0.0100
# episode: 108 | score avg: 192.30 | memory length: 2000 | epsilon: 0.0100
# episode: 109 | score avg: 188.87 | memory length: 2000 | epsilon: 0.0100
# episode: 110 | score avg: 185.38 | memory length: 2000 | epsilon: 0.0100
# episode: 111 | score avg: 182.24 | memory length: 2000 | epsilon: 0.0100
# episode: 112 | score avg: 182.82 | memory length: 2000 | epsilon: 0.0100
# episode: 113 | score avg: 180.24 | memory length: 2000 | epsilon: 0.0100
# episode: 114 | score avg: 178.11 | memory length: 2000 | epsilon: 0.0100
# episode: 115 | score avg: 178.30 | memory length: 2000 | epsilon: 0.0100
# episode: 116 | score avg: 176.17 | memory length: 2000 | epsilon: 0.0100
# episode: 117 | score avg: 173.06 | memory length: 2000 | epsilon: 0.0100
# episode: 118 | score avg: 169.15 | memory length: 2000 | epsilon: 0.0100
# episode: 119 | score avg: 166.03 | memory length: 2000 | epsilon: 0.0100
# episode: 120 | score avg: 164.23 | memory length: 2000 | epsilon: 0.0100
# episode: 121 | score avg: 168.11 | memory length: 2000 | epsilon: 0.0100
# episode: 122 | score avg: 171.00 | memory length: 2000 | epsilon: 0.0100
# episode: 123 | score avg: 169.50 | memory length: 2000 | epsilon: 0.0100
# episode: 124 | score avg: 170.55 | memory length: 2000 | epsilon: 0.0100
# episode: 125 | score avg: 168.59 | memory length: 2000 | epsilon: 0.0100
# episode: 126 | score avg: 165.03 | memory length: 2000 | epsilon: 0.0100
# episode: 127 | score avg: 163.73 | memory length: 2000 | epsilon: 0.0100
# episode: 128 | score avg: 160.86 | memory length: 2000 | epsilon: 0.0100
# episode: 129 | score avg: 161.17 | memory length: 2000 | epsilon: 0.0100
# episode: 130 | score avg: 158.45 | memory length: 2000 | epsilon: 0.0100
# episode: 131 | score avg: 156.01 | memory length: 2000 | epsilon: 0.0100
# episode: 132 | score avg: 155.61 | memory length: 2000 | epsilon: 0.0100
# episode: 133 | score avg: 155.15 | memory length: 2000 | epsilon: 0.0100
# episode: 134 | score avg: 155.13 | memory length: 2000 | epsilon: 0.0100
# episode: 135 | score avg: 153.72 | memory length: 2000 | epsilon: 0.0100
# episode: 136 | score avg: 156.05 | memory length: 2000 | epsilon: 0.0100
# episode: 137 | score avg: 155.24 | memory length: 2000 | epsilon: 0.0100
# episode: 138 | score avg: 155.62 | memory length: 2000 | epsilon: 0.0100
# episode: 139 | score avg: 154.96 | memory length: 2000 | epsilon: 0.0100
# episode: 140 | score avg: 155.96 | memory length: 2000 | epsilon: 0.0100
# episode: 141 | score avg: 164.36 | memory length: 2000 | epsilon: 0.0100
# episode: 142 | score avg: 162.43 | memory length: 2000 | epsilon: 0.0100
# episode: 143 | score avg: 157.09 | memory length: 2000 | epsilon: 0.0100
# episode: 144 | score avg: 155.48 | memory length: 2000 | epsilon: 0.0100
# episode: 145 | score avg: 162.63 | memory length: 2000 | epsilon: 0.0100
# episode: 146 | score avg: 163.07 | memory length: 2000 | epsilon: 0.0100
# episode: 147 | score avg: 162.86 | memory length: 2000 | epsilon: 0.0100
# episode: 148 | score avg: 163.87 | memory length: 2000 | epsilon: 0.0100
# episode: 149 | score avg: 165.59 | memory length: 2000 | epsilon: 0.0100
# episode: 150 | score avg: 171.03 | memory length: 2000 | epsilon: 0.0100
# episode: 151 | score avg: 171.72 | memory length: 2000 | epsilon: 0.0100
# episode: 152 | score avg: 171.95 | memory length: 2000 | epsilon: 0.0100
# episode: 153 | score avg: 173.66 | memory length: 2000 | epsilon: 0.0100
# episode: 154 | score avg: 176.49 | memory length: 2000 | epsilon: 0.0100
# episode: 155 | score avg: 180.04 | memory length: 2000 | epsilon: 0.0100
# episode: 156 | score avg: 180.54 | memory length: 2000 | epsilon: 0.0100
# episode: 157 | score avg: 180.38 | memory length: 2000 | epsilon: 0.0100
# episode: 158 | score avg: 179.95 | memory length: 2000 | epsilon: 0.0100
# episode: 159 | score avg: 178.15 | memory length: 2000 | epsilon: 0.0100
# episode: 160 | score avg: 179.24 | memory length: 2000 | epsilon: 0.0100
# episode: 161 | score avg: 181.81 | memory length: 2000 | epsilon: 0.0100
# episode: 162 | score avg: 183.23 | memory length: 2000 | epsilon: 0.0100
# episode: 163 | score avg: 184.11 | memory length: 2000 | epsilon: 0.0100
# episode: 164 | score avg: 185.90 | memory length: 2000 | epsilon: 0.0100
# episode: 165 | score avg: 187.41 | memory length: 2000 | epsilon: 0.0100
# episode: 166 | score avg: 188.67 | memory length: 2000 | epsilon: 0.0100
# episode: 167 | score avg: 188.20 | memory length: 2000 | epsilon: 0.0100
# episode: 168 | score avg: 190.88 | memory length: 2000 | epsilon: 0.0100
# episode: 169 | score avg: 194.89 | memory length: 2000 | epsilon: 0.0100
# episode: 170 | score avg: 199.00 | memory length: 2000 | epsilon: 0.0100
# episode: 171 | score avg: 229.10 | memory length: 2000 | epsilon: 0.0100
# episode: 172 | score avg: 230.99 | memory length: 2000 | epsilon: 0.0100
# episode: 173 | score avg: 243.79 | memory length: 2000 | epsilon: 0.0100
# episode: 174 | score avg: 251.81 | memory length: 2000 | epsilon: 0.0100
# episode: 175 | score avg: 250.73 | memory length: 2000 | epsilon: 0.0100
# episode: 176 | score avg: 275.66 | memory length: 2000 | epsilon: 0.0100
# episode: 177 | score avg: 268.29 | memory length: 2000 | epsilon: 0.0100
# episode: 178 | score avg: 266.36 | memory length: 2000 | epsilon: 0.0100
# episode: 179 | score avg: 259.83 | memory length: 2000 | epsilon: 0.0100
# episode: 180 | score avg: 262.94 | memory length: 2000 | epsilon: 0.0100
# episode: 181 | score avg: 255.85 | memory length: 2000 | epsilon: 0.0100
# episode: 182 | score avg: 250.07 | memory length: 2000 | epsilon: 0.0100
# episode: 183 | score avg: 251.06 | memory length: 2000 | epsilon: 0.0100
# episode: 184 | score avg: 256.65 | memory length: 2000 | epsilon: 0.0100
# episode: 185 | score avg: 275.09 | memory length: 2000 | epsilon: 0.0100
# episode: 186 | score avg: 267.08 | memory length: 2000 | epsilon: 0.0100
# episode: 187 | score avg: 265.57 | memory length: 2000 | epsilon: 0.0100
# episode: 188 | score avg: 254.51 | memory length: 2000 | epsilon: 0.0100
# episode: 189 | score avg: 245.66 | memory length: 2000 | epsilon: 0.0100
# episode: 190 | score avg: 236.90 | memory length: 2000 | epsilon: 0.0100
# episode: 191 | score avg: 244.41 | memory length: 2000 | epsilon: 0.0100
# episode: 192 | score avg: 249.07 | memory length: 2000 | epsilon: 0.0100
# episode: 193 | score avg: 248.86 | memory length: 2000 | epsilon: 0.0100
# episode: 194 | score avg: 240.57 | memory length: 2000 | epsilon: 0.0100
# episode: 195 | score avg: 235.92 | memory length: 2000 | epsilon: 0.0100
# episode: 196 | score avg: 213.52 | memory length: 2000 | epsilon: 0.0100
# episode: 197 | score avg: 209.47 | memory length: 2000 | epsilon: 0.0100
# episode: 198 | score avg: 220.62 | memory length: 2000 | epsilon: 0.0100
# episode: 199 | score avg: 213.36 | memory length: 2000 | epsilon: 0.0100
# episode: 200 | score avg: 217.63 | memory length: 2000 | epsilon: 0.0100
# episode: 201 | score avg: 223.16 | memory length: 2000 | epsilon: 0.0100
# episode: 202 | score avg: 235.75 | memory length: 2000 | epsilon: 0.0100
# episode: 203 | score avg: 244.07 | memory length: 2000 | epsilon: 0.0100
# episode: 204 | score avg: 245.67 | memory length: 2000 | epsilon: 0.0100
# episode: 205 | score avg: 252.30 | memory length: 2000 | epsilon: 0.0100
# episode: 206 | score avg: 249.37 | memory length: 2000 | epsilon: 0.0100
# episode: 207 | score avg: 241.43 | memory length: 2000 | epsilon: 0.0100
# episode: 208 | score avg: 239.99 | memory length: 2000 | epsilon: 0.0100
# episode: 209 | score avg: 234.19 | memory length: 2000 | epsilon: 0.0100
# episode: 210 | score avg: 227.07 | memory length: 2000 | epsilon: 0.0100
# episode: 211 | score avg: 223.26 | memory length: 2000 | epsilon: 0.0100
# episode: 212 | score avg: 220.24 | memory length: 2000 | epsilon: 0.0100
# episode: 213 | score avg: 226.21 | memory length: 2000 | epsilon: 0.0100
# episode: 214 | score avg: 231.89 | memory length: 2000 | epsilon: 0.0100
# episode: 215 | score avg: 256.10 | memory length: 2000 | epsilon: 0.0100
# episode: 216 | score avg: 260.09 | memory length: 2000 | epsilon: 0.0100
# episode: 217 | score avg: 260.58 | memory length: 2000 | epsilon: 0.0100
# episode: 218 | score avg: 261.63 | memory length: 2000 | epsilon: 0.0100
# episode: 219 | score avg: 269.16 | memory length: 2000 | epsilon: 0.0100
# episode: 220 | score avg: 269.25 | memory length: 2000 | epsilon: 0.0100
# episode: 221 | score avg: 257.72 | memory length: 2000 | epsilon: 0.0100
# episode: 222 | score avg: 256.05 | memory length: 2000 | epsilon: 0.0100
# episode: 223 | score avg: 249.54 | memory length: 2000 | epsilon: 0.0100
# episode: 224 | score avg: 240.59 | memory length: 2000 | epsilon: 0.0100
# episode: 225 | score avg: 233.03 | memory length: 2000 | epsilon: 0.0100
# episode: 226 | score avg: 227.43 | memory length: 2000 | epsilon: 0.0100
# episode: 227 | score avg: 221.19 | memory length: 2000 | epsilon: 0.0100
# episode: 228 | score avg: 215.17 | memory length: 2000 | epsilon: 0.0100
# episode: 229 | score avg: 209.25 | memory length: 2000 | epsilon: 0.0100
# episode: 230 | score avg: 203.83 | memory length: 2000 | epsilon: 0.0100
# episode: 231 | score avg: 199.64 | memory length: 2000 | epsilon: 0.0100
# episode: 232 | score avg: 196.18 | memory length: 2000 | epsilon: 0.0100
# episode: 233 | score avg: 196.16 | memory length: 2000 | epsilon: 0.0100
# episode: 234 | score avg: 192.04 | memory length: 2000 | epsilon: 0.0100
# episode: 235 | score avg: 188.04 | memory length: 2000 | epsilon: 0.0100
# episode: 236 | score avg: 187.14 | memory length: 2000 | epsilon: 0.0100
# episode: 237 | score avg: 185.32 | memory length: 2000 | epsilon: 0.0100
# episode: 238 | score avg: 185.79 | memory length: 2000 | epsilon: 0.0100
# episode: 239 | score avg: 183.11 | memory length: 2000 | epsilon: 0.0100
# episode: 240 | score avg: 180.90 | memory length: 2000 | epsilon: 0.0100
# episode: 241 | score avg: 179.41 | memory length: 2000 | epsilon: 0.0100
# episode: 242 | score avg: 178.47 | memory length: 2000 | epsilon: 0.0100
# episode: 243 | score avg: 175.52 | memory length: 2000 | epsilon: 0.0100
# episode: 244 | score avg: 173.67 | memory length: 2000 | epsilon: 0.0100
# episode: 245 | score avg: 172.70 | memory length: 2000 | epsilon: 0.0100
# episode: 246 | score avg: 169.73 | memory length: 2000 | epsilon: 0.0100
# episode: 247 | score avg: 170.86 | memory length: 2000 | epsilon: 0.0100
# episode: 248 | score avg: 170.47 | memory length: 2000 | epsilon: 0.0100
# episode: 249 | score avg: 170.23 | memory length: 2000 | epsilon: 0.0100
# episode: 250 | score avg: 170.90 | memory length: 2000 | epsilon: 0.0100
# episode: 251 | score avg: 173.71 | memory length: 2000 | epsilon: 0.0100
# episode: 252 | score avg: 174.64 | memory length: 2000 | epsilon: 0.0100
# episode: 253 | score avg: 188.18 | memory length: 2000 | epsilon: 0.0100
# episode: 254 | score avg: 200.86 | memory length: 2000 | epsilon: 0.0100
# episode: 255 | score avg: 204.17 | memory length: 2000 | epsilon: 0.0100
# episode: 256 | score avg: 207.56 | memory length: 2000 | epsilon: 0.0100
# episode: 257 | score avg: 211.60 | memory length: 2000 | epsilon: 0.0100
# episode: 258 | score avg: 216.34 | memory length: 2000 | epsilon: 0.0100
# episode: 259 | score avg: 220.41 | memory length: 2000 | epsilon: 0.0100
# episode: 260 | score avg: 223.47 | memory length: 2000 | epsilon: 0.0100
# episode: 261 | score avg: 225.42 | memory length: 2000 | epsilon: 0.0100
# episode: 262 | score avg: 233.38 | memory length: 2000 | epsilon: 0.0100
# episode: 263 | score avg: 242.34 | memory length: 2000 | epsilon: 0.0100
# episode: 264 | score avg: 266.81 | memory length: 2000 | epsilon: 0.0100
# episode: 265 | score avg: 267.33 | memory length: 2000 | epsilon: 0.0100
# episode: 266 | score avg: 274.39 | memory length: 2000 | epsilon: 0.0100
# episode: 267 | score avg: 284.85 | memory length: 2000 | epsilon: 0.0100
# episode: 268 | score avg: 306.37 | memory length: 2000 | epsilon: 0.0100
# episode: 269 | score avg: 315.63 | memory length: 2000 | epsilon: 0.0100
# episode: 270 | score avg: 334.07 | memory length: 2000 | epsilon: 0.0100
# episode: 271 | score avg: 350.66 | memory length: 2000 | epsilon: 0.0100
# episode: 272 | score avg: 353.70 | memory length: 2000 | epsilon: 0.0100
# episode: 273 | score avg: 355.43 | memory length: 2000 | epsilon: 0.0100
# episode: 274 | score avg: 367.38 | memory length: 2000 | epsilon: 0.0100
# episode: 275 | score avg: 377.34 | memory length: 2000 | epsilon: 0.0100
# episode: 276 | score avg: 389.61 | memory length: 2000 | epsilon: 0.0100
# episode: 277 | score avg: 400.65 | memory length: 2000 | epsilon: 0.0100
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2890: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# ### 4. LossSurface

# %%
def loss_surface(agent, alpha, beta):
         
    np.random.seed(0)
    ## 1. Checkpoint 에 훈련을 마친 Weights 를 모델에 로드하기 
    checkpoint_path = "./save_model/model"
    agent.model.load_weights(checkpoint_path)

    ## 2. 0~5 개의 가중치를 불러옴. 
    w0 = agent.model.get_weights()[0] + alpha * np.random.randn(agent.model.get_weights()[0].shape[0], agent.model.get_weights()[0].shape[1]) + beta * np.random.randn(agent.model.get_weights()[0].shape[0],agent.model.get_weights()[0].shape[1])
    w1 = agent.model.get_weights()[1] +  alpha * np.random.randn(agent.model.get_weights()[1].shape[0],)
    w2 = agent.model.get_weights()[2] + alpha * np.random.randn(agent.model.get_weights()[2].shape[0], agent.model.get_weights()[2].shape[1]) + beta * np.random.randn(agent.model.get_weights()[2].shape[0],agent.model.get_weights()[2].shape[1])
    w3 = agent.model.get_weights()[3] +  alpha * np.random.randn(agent.model.get_weights()[3].shape[0],)
    w4 = agent.model.get_weights()[4] + alpha * np.random.randn(agent.model.get_weights()[4].shape[0], agent.model.get_weights()[4].shape[1]) + beta * np.random.randn(agent.model.get_weights()[4].shape[0],agent.model.get_weights()[4].shape[1])
    w5 = agent.model.get_weights()[5] +  alpha * np.random.randn(agent.model.get_weights()[5].shape[0],) + beta * np.random.randn(agent.model.get_weights()[5].shape[0],)

    agent.model.set_weights([w0,w1,w2,w3,w4,w5])
        
    return agent.test_model().numpy() # Loss 를 반환함.

# %%
ms = np.linspace(-1.0, 1.0, 10)
bs = np.linspace(-1.0, 1.0, 10)

M, B = np.meshgrid(ms, bs)

zs = np.array([loss_surface(agent, alpha, beta) for alpha, beta in zip(np.ravel(M), np.ravel(B))])
Z = zs.reshape(M.shape)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(M, B, Z, rstride=1, cstride=1, cmap=cm.coolwarm, alpha=0.5)

# ax.set_xlabel('m')
# ax.set_ylabel('b')
# ax.set_zlabel('error')
# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot( 111, projection="3d" )

surf = ax.plot_surface( M,B, Z )

ax.set_zlim(0, 900)
plt.show()
